# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv('Salary_dataset.csv')
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
plt.scatter(df['Salary'],df['YearsExperience'])

# %%
X=df[['Unnamed: 0','YearsExperience',]]
y = df['Salary']

# %%
X
# Out:
#     Unnamed: 0  YearsExperience
# 0            0              1.2
# 1            1              1.4
# 2            2              1.6
# 3            3              2.1
# 4            4              2.3
# 5            5              3.0
# 6            6              3.1
# 7            7              3.3
# 8            8              3.3
# 9            9              3.8
# 10          10              4.0
# 11          11              4.1
# 12          12              4.1
# 13          13              4.2
# 14          14              4.6
# 15          15              5.0
# 16          16              5.2
# 17          17              5.4
# 18          18              6.0
# 19          19              6.1
# 20          20              6.9
# 21          21              7.2
# 22          22              8.0
# 23          23              8.3
# 24          24              8.8
# 25          25              9.1
# 26          26              9.6
# 27          27              9.7
# ...

# %%
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.75)

# %%
print("i am X train\n",X_train)
print("i am X test\n",X_test)
print("i am y train\n",y_train)
print("i am y test\n",y_test)
# Out:
# i am X train
#      Unnamed: 0  YearsExperience
# 10          10              4.0
# 23          23              8.3
# 3            3              2.1
# 1            1              1.4
# 21          21              7.2
# 25          25              9.1
# 27          27              9.7
# 12          12              4.1
# 5            5              3.0
# 2            2              1.6
# 7            7              3.3
# 17          17              5.4
# 24          24              8.8
# 4            4              2.3
# 20          20              6.9
# 28          28             10.4
# 6            6              3.1
# 15          15              5.0
# 11          11              4.1
# 18          18              6.0
# 9            9              3.8
# 13          13              4.2
# i am X test
#      Unnamed: 0  YearsExperience
# 26          26              9.6
# 0            0              1.2
# 29          29             10.6
# 16          16              5.2
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([116724.14204905,  36120.79280482, 126376.70104921,  72340.29701989,
#         55375.10569629,  66668.29820907,  80848.29523611, 100801.90129168])

# %%
y_test
# Out:
# 26    116970.0
# 0      39344.0
# 29    121873.0
# 16     66030.0
# 8      64446.0
# 14     61112.0
# 19     93941.0
# 22    101303.0
# Name: Salary, dtype: float64

# %%
model.score(X_test,y_test)
# Out:
# 0.942091034469346

# %%
X = df[['YearsExperience']]
y = df['Salary']

X_train, X_test, y_train, y_test =train_test_split(X,y,train_size=0.80)
model = LinearRegression()
model.fit(X_train, y_train)
print(model.score(X_test,y_test))
# Out:
# 0.898550741856367

# %%
plt.scatter(df['YearsExperience'], df['Salary'], color='blue', label='Actual', marker='*')
plt.plot(df['YearsExperience'], model.predict(df[['YearsExperience']]), color='red', label='Predicted')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience')
plt.legend()
plt.show()
