# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv('performance.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    30000         2          37000
# 11    80000         7          16000
# 12    48000         3          33000
# 13    62000         5          25000
# 14   100000         9           9500

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
X = df[['Mileage','Age(yrs)']]
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    30000         2
# 11    80000         7
# 12    48000         3
# 13    62000         5
# 14   100000         9

# %%
y = df['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    37000
# 11    16000
# 12    33000
# 13    25000
# 14     9500
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state=0)

# %%
print("i am X train\n",X_train)
print("i am X test\n",X_test)
print("i am y train\n",y_train)
print("i am y test\n",y_test)
# Out:
# i am X train
#      Mileage  Age(yrs)
# 9     67000         6
# 14   100000         9
# 4     46000         4
# 2     57000         5
# 13    62000         5
# 10    30000         2
# 7     72000         6
# 11    80000         7
# 3     22500         2
# 0     69000         6
# 5     59000         5
# 12    48000         3
# i am X test
#     Mileage  Age(yrs)
# 1    35000         3
# 6    52000         5
# 8    91000         8
# i am y train
#  9     22000
# 14     9500
# 4     31500
# 2     26100
# 13    25000
# 10    37000
# 7     19300
# 11    16000
# 3     40000
# 0     18000
# 5     26750
# 12    33000
# Name: Sell Price($), dtype: int64
# i am y test
#  1    34000
# 6    32000
# 8    12000
# Name: Sell Price($), dtype: int64

# %%
len(X_train)
# Out:
# 12

# %%
len(X_test)
# Out:
# 3

# %%
model = linear_model.LinearRegression() #from sklearn import linear_model

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([34907.910224 , 27005.1797928, 12113.6363897])

# %%
y_test
# Out:
# 1    34000
# 6    32000
# 8    12000
# Name: Sell Price($), dtype: int64

# %%
model.score(X_test,y_test)
# Out:
# 0.9128870165333544
